# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.12/dist-packages (1.2.1)
# The nvcc4jupyter extension is already loaded. To reload it, use:
#   %reload_ext nvcc4jupyter

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# fatal: destination path 'sci_pract2_cuda' already exists and is not an empty directory.
# /content/sci_pract2_cuda
# Already up to date.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 10 (delta 6), reused 9 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 3.82 KiB | 1.27 MiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    3d08bf1..8d3d1c5  main       -> origin/main
# Updating 3d08bf1..8d3d1c5
# Fast-forward
#  pract2.ipynb      | 31 ++++++++++++++++++++++++++-----
#  vector_add_mod.cu | 38 +++++++++++++++++++++++++++++++++-----
#  2 files changed, 59 insertions(+), 10 deletions(-)

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod
# Out:
# ./vector_add_mod.cu(25): error: no instance of overloaded function "cudaMalloc" matches the argument list
#             argument types are: (unsigned long)
#       float* a_cuda = cudaMalloc(sizeof(float) * 100000000);
#                       ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime_api.h(5363): note #3322-D: number of parameters of function "cudaMalloc(void **, size_t)" does not match the call
#   extern __attribute__((host)) __attribute__((cudart_builtin)) cudaError_t cudaMalloc(void **devPtr, size_t size);
#                                                                            ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime.h(761): note #3322-D: number of parameters of function template "cudaMalloc(T **, size_t)" does not match the call
#   static __inline__ __attribute__((host)) cudaError_t cudaMalloc(
#                                                       ^
#
# ./vector_add_mod.cu(26): error: no instance of overloaded function "cudaMalloc" matches the argument list
#             argument types are: (unsigned long)
#       float* b_cuda = cudaMalloc(sizeof(float) * 100000000);
#                       ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime_api.h(5363): note #3322-D: number of parameters of function "cudaMalloc(void **, size_t)" does not match the call
#   extern __attribute__((host)) __attribute__((cudart_builtin)) cudaError_t cudaMalloc(void **devPtr, size_t size);
#                                                                            ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime.h(761): note #3322-D: number of parameters of function template "cudaMalloc(T **, size_t)" does not match the call
#   static __inline__ __attribute__((host)) cudaError_t cudaMalloc(
#                                                       ^
#
# ./vector_add_mod.cu(27): error: no instance of overloaded function "cudaMalloc" matches the argument list
#             argument types are: (unsigned long)
#       float* out_cuda = cudaMalloc(sizeof(float) * 100000000);
#                         ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime_api.h(5363): note #3322-D: number of parameters of function "cudaMalloc(void **, size_t)" does not match the call
#   extern __attribute__((host)) __attribute__((cudart_builtin)) cudaError_t cudaMalloc(void **devPtr, size_t size);
#                                                                            ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cuda_runtime.h(761): note #3322-D: number of parameters of function template "cudaMalloc(T **, size_t)" does not match the call
#   static __inline__ __attribute__((host)) cudaError_t cudaMalloc(
#                                                       ^
#
# 3 errors detected in the compilation of "./vector_add_mod.cu".
# Test
