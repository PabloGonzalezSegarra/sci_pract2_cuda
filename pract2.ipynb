# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.12/dist-packages (1.2.1)
# The nvcc4jupyter extension is already loaded. To reload it, use:
#   %reload_ext nvcc4jupyter

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# fatal: destination path 'sci_pract2_cuda' already exists and is not an empty directory.
# /content/sci_pract2_cuda
# Already up to date.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 1), reused 4 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.66 KiB | 565.00 KiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    a99ab3d..3d08bf1  main       -> origin/main
# Updating a99ab3d..3d08bf1
# Fast-forward
#  gpu_check.cu | 37 +++++++++++++++++++++++++++++++++++++
#  pract2.ipynb | 27 +++++++++++++++++++++++----
#  2 files changed, 60 insertions(+), 4 deletions(-)
#  create mode 100644 gpu_check.cu

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod
# Out:
# ./vector_add_mod.cu(1): error: expected a declaration
#   %%cuda --arch=sm_75
#   ^
#
# /usr/include/x86_64-linux-gnu/bits/types/__fpos_t.h(13): error: identifier "__mbstate_t" is undefined
#     __mbstate_t __state;
#     ^
#
# /usr/include/x86_64-linux-gnu/bits/types/__fpos64_t.h(13): error: identifier "__mbstate_t" is undefined
#     __mbstate_t __state;
#     ^
#
# /usr/include/stdio.h(52): error: identifier "__gnuc_va_list" is undefined
#   typedef __gnuc_va_list va_list;
#           ^
#
# /usr/include/stdio.h(366): error: identifier "__gnuc_va_list" is undefined
#          __gnuc_va_list __arg);
#          ^
#
# /usr/include/stdio.h(371): error: identifier "__gnuc_va_list" is undefined
#   extern int vprintf (const char *__restrict __format, __gnuc_va_list __arg);
#                                                        ^
#
# /usr/include/stdio.h(374): error: identifier "__gnuc_va_list" is undefined
#          __gnuc_va_list __arg) noexcept (true);
#          ^
#
# /usr/include/stdio.h(383): error: identifier "__gnuc_va_list" is undefined
#           const char *__restrict __format, __gnuc_va_list __arg)
#                                            ^
#
# /usr/include/stdio.h(391): error: identifier "__gnuc_va_list" is undefined
#           __gnuc_va_list __arg)
#           ^
#
# /usr/include/stdio.h(404): error: identifier "__gnuc_va_list" is undefined
#          __gnuc_va_list __arg)
#          ^
#
# /usr/include/stdio.h(460): error: identifier "__gnuc_va_list" is undefined
#         __gnuc_va_list __arg)
#         ^
#
# /usr/include/stdio.h(467): error: identifier "__gnuc_va_list" is undefined
#   extern int vscanf (const char *__restrict __format, __gnuc_va_list __arg)
#                                                       ^
#
# /usr/include/stdio.h(472): error: identifier "__gnuc_va_list" is undefined
#         const char *__restrict __format, __gnuc_va_list __arg)
#                                          ^
#
# /usr/include/stdio.h(479): error: identifier "__gnuc_va_list" is undefined
#   extern int vfscanf (FILE *__restrict __s, const char *__restrict __format, __gnuc_va_list __arg) __asm__ ("" "__isoc99_vfscanf")
#                                                                              ^
#
# /usr/include/stdio.h(484): error: identifier "__gnuc_va_list" is undefined
#   extern int vscanf (const char *__restrict __format, __gnuc_va_list __arg) __asm__ ("" "__isoc99_vscanf")
#                                                       ^
#
# /usr/include/stdio.h(487): error: identifier "__gnuc_va_list" is undefined
#   extern int vsscanf (const char *__restrict __s, const char *__restrict __format, __gnuc_va_list __arg) noexcept (true) __asm__ ("" "__isoc99_vsscanf")
#                                                                                    ^
#
# /usr/include/stdio.h(858): error: identifier "__gnuc_va_list" is undefined
#          __gnuc_va_list __args)
#          ^
#
# /usr/include/stdio.h(902): error: expected a declaration
#   }
#   ^
#
# 18 errors detected in the compilation of "./vector_add_mod.cu".
# Test
