# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.12/dist-packages (1.2.1)
# The nvcc4jupyter extension is already loaded. To reload it, use:
#   %reload_ext nvcc4jupyter

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# fatal: destination path 'sci_pract2_cuda' already exists and is not an empty directory.
# /content/sci_pract2_cuda
# Already up to date.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !git pull > /dev/null 2>&1
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod

# %%
# !nvcc -arch=sm_75 ./vector_add_cpu.cu -o vector_add_cpu
# !./vector_add_cpu 
# !./vector_add_cpu
# !./vector_add_cpu
# !./vector_add_cpu
# !./vector_add_cpu

# %%
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# Out:
# Using 100000000 blocks of 1 threads
# Time elapsed: 707.120667 ms
# Success! All values are correct.
# Using 100000000 blocks of 1 threads
# Time elapsed: 557.230225 ms
# Success! All values are correct.
# Using 100000000 blocks of 1 threads
# Time elapsed: 532.398499 ms
# Success! All values are correct.
# Using 100000000 blocks of 1 threads
# Time elapsed: 539.879883 ms
# Success! All values are correct.
# Using 100000000 blocks of 1 threads
# Time elapsed: 535.306702 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# Out:
# Using 6250000 blocks of 16 threads
# Time elapsed: 443.743164 ms
# Success! All values are correct.
# Using 6250000 blocks of 16 threads
# Time elapsed: 444.634766 ms
# Success! All values are correct.
# Using 6250000 blocks of 16 threads
# Time elapsed: 495.731628 ms
# Success! All values are correct.
# Using 6250000 blocks of 16 threads
# Time elapsed: 446.233063 ms
# Success! All values are correct.
# Using 6250000 blocks of 16 threads
# Time elapsed: 448.105469 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# Out:
# Using 3125000 blocks of 32 threads
# Time elapsed: 442.131348 ms
# Success! All values are correct.
# Using 3125000 blocks of 32 threads
# Time elapsed: 434.043915 ms
# Success! All values are correct.
# Using 3125000 blocks of 32 threads
# Time elapsed: 440.561035 ms
# Success! All values are correct.
# Using 3125000 blocks of 32 threads
# Time elapsed: 440.625793 ms
# Success! All values are correct.
# Using 3125000 blocks of 32 threads
# Time elapsed: 513.059204 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# Out:
# Using 390625 blocks of 256 threads
# Time elapsed: 434.066345 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 434.234528 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 434.039307 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 428.707275 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 433.209930 ms
# Success! All values are correct.
