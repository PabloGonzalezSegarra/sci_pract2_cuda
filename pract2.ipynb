# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.12/dist-packages (1.2.1)
# The nvcc4jupyter extension is already loaded. To reload it, use:
#   %reload_ext nvcc4jupyter

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# fatal: destination path 'sci_pract2_cuda' already exists and is not an empty directory.
# /content/sci_pract2_cuda
# Already up to date.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.40 KiB | 1.40 MiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    0ea95b5..48fb08f  main       -> origin/main
# Updating 0ea95b5..48fb08f
# Fast-forward
#  pract2.ipynb      | 36 ++++++++++++++++++------------------
#  vector_add_mod.cu | 17 +++++++++++------
#  2 files changed, 29 insertions(+), 24 deletions(-)

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod
# Out:
# Error at index 0: 0.000000 (diff=3.000000)
