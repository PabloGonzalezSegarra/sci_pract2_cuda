# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# ...
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmpr2fke0t4".

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# Cloning into 'sci_pract2_cuda'...
# remote: Enumerating objects: 343, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 343 (delta 69), reused 69 (delta 36), pack-reused 237 (from 1)
# Receiving objects: 100% (343/343), 1.02 MiB | 21.73 MiB/s, done.
# Resolving deltas: 100% (219/219), done.
# /content/sci_pract2_cuda

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !git pull > /dev/null 2>&1
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod

# %%
# !nvcc -arch=sm_75 ./ej6_cpu.cu -o ej6_cpu
# !./ej6_cpu 
# !./ej6_cpu
# !./ej6_cpu
# !./ej6_cpu
# !./ej6_cpu
# Out:
# Elapsed time: 225730.731701 ms
# GFLOPS: 0.177202
# Elapsed time: 225775.363480 ms
# GFLOPS: 0.177167
# Elapsed time: 225413.030444 ms
# GFLOPS: 0.177452
# Elapsed time: 224690.438361 ms
# GFLOPS: 0.178023
# Elapsed time: 224934.833417 ms
# GFLOPS: 0.177829

# %%
# !nvcc -arch=sm_75 ./ej6.cu -o ej6

# !./ej6 256
# !./ej6 256
# !./ej6 256
# !./ej6 256
# !./ej6 256
# Out:
# Using 390625 blocks of 256 threads
# Time elapsed: 10333.632812 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10465.818359 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10696.263672 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10909.836914 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 11034.091797 ms
# Success! All values are correct.

# %% [markdown]
# --

# %%
# !git pull
# Out:
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 9 (delta 5), reused 9 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 4.31 KiB | 1.44 MiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    aa7eb8b..5073ae6  main       -> origin/main
# Updating aa7eb8b..5073ae6
# Fast-forward
#  ej8.txt                 |  11 +-
#  ej8_optimized.cu        |   4 +-
#  ej8_results/n_small.txt | 257 ++++++++++++-----------
#  ej8_results/sum_cpu.txt |  23 ++
#  ej8_ultra_optimized.cu  |   2 +-
#  pract2.ipynb            | 542 +++++++++++++++++++++++-------------------------
#  6 files changed, 424 insertions(+), 415 deletions(-)

# %% [markdown]
# ## CPU

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_cpu.cu -o ej8_cpu

# %%
# !./ej8_cpu
# Out:
# Elapsed time: 321488.295125 ms

# %% [markdown]
# Elapsed time: 324755.684563 ms

# %% [markdown]
# ## GPU - Sin optimizar

# %%
# !nvcc -O3 -arch=sm_75 ./ej8.cu -o ej8

# %%
# !./ej8 128
# !./ej8 128
# !./ej8 128
# !./ej8 128
# !./ej8 128

# !./ej8 256
# !./ej8 256
# !./ej8 256
# !./ej8 256
# !./ej8 256

# !./ej8 512
# !./ej8 512
# !./ej8 512
# !./ej8 512
# !./ej8 512
# Out:
# Using 7813 blocks of 128 threads
# Time elapsed: 4496.817383 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Time elapsed: 4389.302734 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Time elapsed: 4395.071289 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Time elapsed: 4402.246094 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Time elapsed: 4431.773438 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 256 threads
# Time elapsed: 4437.092773 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 256 threads
# Time elapsed: 4435.747070 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 256 threads
# Time elapsed: 4446.516602 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# ...

# %%
# !./ej8 64
# !./ej8 64
# !./ej8 64
# !./ej8 64
# !./ej8 64
# Out:
# Using 15625 blocks of 64 threads
# Time elapsed: 4552.622559 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Time elapsed: 4453.951172 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Time elapsed: 4470.878418 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Time elapsed: 4503.976074 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Time elapsed: 4547.502930 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!

# %% [markdown]
# ## GPU - Pre-calculando la suma de b

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_optimized.cu -o ej8_optimized

# %%
# !./ej8_optimized 64
# !./ej8_optimized 64
# !./ej8_optimized 64
# !./ej8_optimized 64
# !./ej8_optimized 64

# !./ej8_optimized 128
# !./ej8_optimized 128
# !./ej8_optimized 128
# !./ej8_optimized 128
# !./ej8_optimized 128

# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256

# !./ej8_optimized 512
# !./ej8_optimized 512
# !./ej8_optimized 512
# !./ej8_optimized 512
# !./ej8_optimized 512
# Out:
# Using 1562500 blocks of 64 threads
# Time elapsed: 134.562439 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 1562500 blocks of 64 threads
# Time elapsed: 133.862625 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 1562500 blocks of 64 threads
# Time elapsed: 135.751129 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 1562500 blocks of 64 threads
# Time elapsed: 134.120514 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 1562500 blocks of 64 threads
# Time elapsed: 134.426331 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 781250 blocks of 128 threads
# Time elapsed: 133.150497 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 781250 blocks of 128 threads
# Time elapsed: 134.165894 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 781250 blocks of 128 threads
# Time elapsed: 134.295837 ms
# ...

# %% [markdown]
# ## GPU - Ejecutando 4 instrucciones por thread para aprovechar el ILP

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_super_optimized.cu -o ej8_super_optimized

# %%
# !./ej8_super_optimized 64
# !./ej8_super_optimized 64
# !./ej8_super_optimized 64
# !./ej8_super_optimized 64
# !./ej8_super_optimized 64

# !./ej8_super_optimized 128
# !./ej8_super_optimized 128
# !./ej8_super_optimized 128
# !./ej8_super_optimized 128
# !./ej8_super_optimized 128

# !./ej8_super_optimized 256
# !./ej8_super_optimized 256
# !./ej8_super_optimized 256
# !./ej8_super_optimized 256
# !./ej8_super_optimized 256


# !./ej8_super_optimized 512
# !./ej8_super_optimized 512
# !./ej8_super_optimized 512
# !./ej8_super_optimized 512
# !./ej8_super_optimized 512
# Out:
# Using 3907 blocks of 64 threads
# Time elapsed: 1.526432 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 64 threads
# Time elapsed: 1.429280 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 64 threads
# Time elapsed: 1.439776 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 64 threads
# Time elapsed: 1.456032 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 64 threads
# Time elapsed: 1.436544 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 128 threads
# Time elapsed: 1.596288 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 128 threads
# Time elapsed: 1.449440 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 128 threads
# Time elapsed: 1.475872 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# ...

# %% [markdown]
# ## GPU - Calculando la suma de b en paralelo

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_ultra_optimized.cu -o ej8_ultra_optimized

# %%
# !./ej8_ultra_optimized 64 2
# Out:
# Using 1562500 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.658432 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!

# %%
# !./ej8_ultra_optimized 64 2
# !./ej8_ultra_optimized 64 2
# !./ej8_ultra_optimized 64 2
# !./ej8_ultra_optimized 64 2
# !./ej8_ultra_optimized 64 2

# !./ej8_ultra_optimized 128 2
# !./ej8_ultra_optimized 128 2
# !./ej8_ultra_optimized 128 2
# !./ej8_ultra_optimized 128 2
# !./ej8_ultra_optimized 128 2

# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2

# !./ej8_ultra_optimized 512 2
# !./ej8_ultra_optimized 512 2
# !./ej8_ultra_optimized 512 2
# !./ej8_ultra_optimized 512 2
# !./ej8_ultra_optimized 512 2
# Out:
# Using 15625 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 1.129376 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 1.314560 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 1.699968 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 0.950560 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 1.589600 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 1.288672 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# ...

# %%
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2

# !./ej8_ultra_optimized 256 4
# !./ej8_ultra_optimized 256 4
# !./ej8_ultra_optimized 256 4
# !./ej8_ultra_optimized 256 4
# !./ej8_ultra_optimized 256 4

# !./ej8_ultra_optimized 256 8
# !./ej8_ultra_optimized 256 8
# !./ej8_ultra_optimized 256 8
# !./ej8_ultra_optimized 256 8
# !./ej8_ultra_optimized 256 8

# !./ej8_ultra_optimized 256 12
# !./ej8_ultra_optimized 256 12
# !./ej8_ultra_optimized 256 12
# !./ej8_ultra_optimized 256 12
# !./ej8_ultra_optimized 256 12
# Out:
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.622398 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.982658 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.528770 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.236862 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.707169 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 4 CPU threads for parallel sum
# Time elapsed: 70.225021 ms
# Expected: 200000000.000000, Got: 200000000.000000
# ...

# %% [markdown]
# ## Desglose de tiempos Suma vs Kernel

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_ultra_optimized_times.cu -o ej8_ultra_optimized_times

# %%
# !./ej8_ultra_optimized_times 256 2
# Out:
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed (total): 72.662819 ms
#   - Parallel sum (CPU): 69.153603 ms
#   - Kernel execution (GPU): 3.500768 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!

# %% [markdown]
# ## Suma en paralelo en la GPU

# %%
# !git pull
# Out:
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 11 (delta 7), reused 11 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (11/11), 4.26 KiB | 1.06 MiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    5073ae6..c7256e6  main       -> origin/main
# Updating 5073ae6..c7256e6
# Fast-forward
#  ej8_results/n_big.txt   |   0
#  ej8_results/n_small.txt |  80 ----------
#  ej8_results/sum_cpu.txt |  25 +++-
#  ej8_results/sum_gpu.txt |  63 ++++++++
#  ej8_sum_gpu.cu          |   4 +-
#  pract2.ipynb            | 389 +++++++++++++++++++++++-------------------------
#  6 files changed, 270 insertions(+), 291 deletions(-)
#  delete mode 100644 ej8_results/n_big.txt

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_sum_gpu.cu -o ej8_sum_gpu

# %%
# !./ej8_sum_gpu 256 256 2048
# Out:
# Using 3906250 blocks of 256 threads for vector_pro
# Using 2048 blocks of 256 threads for sum kernel
# Elements per thread: 1908
# Sum kernel launched
# Time elapsed: 86.990623 ms
# CPU sum: 2000000000.000000, GPU sum: 2000000000.000000
# Expected: 2000000000.000000, Got: 2000000000.000000
# Success!

# %%
# !./ej8_sum_gpu 256 128 256
# !./ej8_sum_gpu 256 128 256
# !./ej8_sum_gpu 256 128 256
# !./ej8_sum_gpu 256 128 256
# !./ej8_sum_gpu 256 128 256
# !./ej8_sum_gpu 256 256 256
# !./ej8_sum_gpu 256 256 256
# !./ej8_sum_gpu 256 256 256
# !./ej8_sum_gpu 256 256 256
# !./ej8_sum_gpu 256 256 256
# !./ej8_sum_gpu 256 512 256
# !./ej8_sum_gpu 256 512 256
# !./ej8_sum_gpu 256 512 256
# !./ej8_sum_gpu 256 512 256
# !./ej8_sum_gpu 256 512 256

# !./ej8_sum_gpu 256 128 512
# !./ej8_sum_gpu 256 128 512
# !./ej8_sum_gpu 256 128 512
# !./ej8_sum_gpu 256 128 512
# !./ej8_sum_gpu 256 128 512
# !./ej8_sum_gpu 256 256 512
# !./ej8_sum_gpu 256 256 512
# !./ej8_sum_gpu 256 256 512
# !./ej8_sum_gpu 256 256 512
# !./ej8_sum_gpu 256 256 512
# !./ej8_sum_gpu 256 512 512
# !./ej8_sum_gpu 256 512 512
# !./ej8_sum_gpu 256 512 512
# !./ej8_sum_gpu 256 512 512
# !./ej8_sum_gpu 256 512 512

# !./ej8_sum_gpu 256 128 1024
# !./ej8_sum_gpu 256 128 1024
# !./ej8_sum_gpu 256 128 1024
# !./ej8_sum_gpu 256 128 1024
# !./ej8_sum_gpu 256 128 1024
# !./ej8_sum_gpu 256 256 1024
# !./ej8_sum_gpu 256 256 1024
# !./ej8_sum_gpu 256 256 1024
# !./ej8_sum_gpu 256 256 1024
# !./ej8_sum_gpu 256 256 1024
# !./ej8_sum_gpu 256 512 1024
# !./ej8_sum_gpu 256 512 1024
# !./ej8_sum_gpu 256 512 1024
# !./ej8_sum_gpu 256 512 1024
# !./ej8_sum_gpu 256 512 1024

# !./ej8_sum_gpu 256 128 2048
# !./ej8_sum_gpu 256 128 2048
# !./ej8_sum_gpu 256 128 2048
# !./ej8_sum_gpu 256 128 2048
# !./ej8_sum_gpu 256 128 2048
# !./ej8_sum_gpu 256 256 2048
# !./ej8_sum_gpu 256 256 2048
# !./ej8_sum_gpu 256 256 2048
# !./ej8_sum_gpu 256 256 2048
# !./ej8_sum_gpu 256 256 2048
# !./ej8_sum_gpu 256 512 2048
# !./ej8_sum_gpu 256 512 2048
# !./ej8_sum_gpu 256 512 2048
# !./ej8_sum_gpu 256 512 2048
# !./ej8_sum_gpu 256 512 2048
# Out:
# Using 390625 blocks of 256 threads for vector_pro
# Using 256 blocks of 128 threads for sum kernel
# Elements per thread: 3052
# Sum kernel launched
# Time elapsed: 8.769376 ms
# CPU sum: 200000000.000000, GPU sum: 200000000.000000
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads for vector_pro
# Using 256 blocks of 128 threads for sum kernel
# Elements per thread: 3052
# Sum kernel launched
# Time elapsed: 8.746848 ms
# CPU sum: 200000000.000000, GPU sum: 200000000.000000
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads for vector_pro
# Using 256 blocks of 128 threads for sum kernel
# Elements per thread: 3052
# Sum kernel launched
# Time elapsed: 8.810592 ms
# CPU sum: 200000000.000000, GPU sum: 200000000.000000
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads for vector_pro
# Using 256 blocks of 128 threads for sum kernel
# ...

# %%
# !./ej8_sum_gpu 256 256 2048
