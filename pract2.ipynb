# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Collecting nvcc4jupyter
#   Downloading nvcc4jupyter-1.2.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading nvcc4jupyter-1.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvcc4jupyter
# Successfully installed nvcc4jupyter-1.2.1
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmpmc3jwpki".

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# Cloning into 'sci_pract2_cuda'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 98 (delta 57), reused 67 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 34.57 KiB | 17.28 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# /content/sci_pract2_cuda

# %%
# !git pull
# Out:
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 2), reused 7 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 3.18 KiB | 1.59 MiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    acd54ba..4d3d946  main       -> origin/main
# Updating acd54ba..4d3d946
# Fast-forward
#  ej5.txt      | 14 +++++++++++
#  ej6.cu       | 69 +++++++++++++++++++++++++++++++++++++++++++++++++++++
#  ej6.txt      | 28 +++++++++++++---------
#  ej7.txt      |  8 +++++++
#  pract2.ipynb | 78 +++++++++++++++++++++++++++---------------------------------
#  5 files changed, 143 insertions(+), 54 deletions(-)
#  create mode 100644 ej5.txt
#  create mode 100644 ej6.cu
#  create mode 100644 ej7.txt

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !git pull > /dev/null 2>&1
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod

# %%
# !nvcc -arch=sm_75 ./ej6_cpu.cu -o ej6_cpu
# !./ej6_cpu 
# !./ej6_cpu
# !./ej6_cpu
# !./ej6_cpu
# !./ej6_cpu
# Out:
# Elapsed time: 225730.731701 ms
# GFLOPS: 0.177202
# Elapsed time: 225775.363480 ms
# GFLOPS: 0.177167
# Elapsed time: 225413.030444 ms
# GFLOPS: 0.177452
# Elapsed time: 224690.438361 ms
# GFLOPS: 0.178023
# Elapsed time: 224934.833417 ms
# GFLOPS: 0.177829

# %%
# !nvcc -arch=sm_75 ./ej6.cu -o ej6

# !./ej6 256
# !./ej6 256
# !./ej6 256
# !./ej6 256
# !./ej6 256
# Out:
# Using 390625 blocks of 256 threads
# Time elapsed: 10333.632812 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10465.818359 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10696.263672 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10909.836914 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 11034.091797 ms
# Success! All values are correct.

# %%
# !git pull > /dev/null 2>&1
# !python analyze_flops.py
# Out:
# ej6.cu - Instrucciones FP:
#   mul\.f32: 2
#   fma\.rn\.f32: 16
#   TOTAL: 18
#
# ej6_cpu.cu - Instrucciones FP:
#   TOTAL: 0

# %%
# !cuobjdump -dis ej6_cpu.cubin | grep -A 500 "heavy_cpu"
# Out:
# cuobjdump fatal   : Unknown option 'dis'
