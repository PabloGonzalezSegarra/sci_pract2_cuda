# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.12/dist-packages (1.2.1)
# The nvcc4jupyter extension is already loaded. To reload it, use:
#   %reload_ext nvcc4jupyter

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# fatal: destination path 'sci_pract2_cuda' already exists and is not an empty directory.
# /content/sci_pract2_cuda
# Already up to date.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.29 KiB | 1.29 MiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    f5486b2..c8f1449  main       -> origin/main
# Updating f5486b2..c8f1449
# Fast-forward
#  ej6_cpu.cu   |   4 +-
#  pract2.ipynb | 141 ++++++++---------------------------------------------------
#  2 files changed, 21 insertions(+), 124 deletions(-)

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !git pull > /dev/null 2>&1
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod

# %%
# !nvcc -arch=sm_75 ./ej6_cpu.cu -o ej6_cpu
# !./ej6_cpu 
# !./ej6_cpu
# !./ej6_cpu
# !./ej6_cpu
# !./ej6_cpu
# Out:
# Elapsed time: 225730.731701 ms
# GFLOPS: 0.177202
# Elapsed time: 225775.363480 ms
# GFLOPS: 0.177167
# Elapsed time: 225413.030444 ms
# GFLOPS: 0.177452
# Elapsed time: 224690.438361 ms
# GFLOPS: 0.178023
# Elapsed time: 224934.833417 ms
# GFLOPS: 0.177829

# %%
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# Out:
# Using 390625 blocks of 256 threads
# Time elapsed: 432.925293 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 432.490997 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 444.291046 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 494.588196 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 433.968018 ms
# Success! All values are correct.
