# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Collecting nvcc4jupyter
#   Downloading nvcc4jupyter-1.2.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading nvcc4jupyter-1.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvcc4jupyter
# Successfully installed nvcc4jupyter-1.2.1
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmp7_eub4n4".

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# Cloning into 'sci_pract2_cuda'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (237/237), done.
# remote: Compressing objects: 100% (172/172), done.
# remote: Total 237 (delta 146), reused 155 (delta 64), pack-reused 0 (from 0)
# Receiving objects: 100% (237/237), 784.19 KiB | 39.21 MiB/s, done.
# Resolving deltas: 100% (146/146), done.
# /content/sci_pract2_cuda

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !git pull > /dev/null 2>&1
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod

# %%
# !nvcc -arch=sm_75 ./ej6_cpu.cu -o ej6_cpu
# !./ej6_cpu 
# !./ej6_cpu
# !./ej6_cpu
# !./ej6_cpu
# !./ej6_cpu
# Out:
# Elapsed time: 225730.731701 ms
# GFLOPS: 0.177202
# Elapsed time: 225775.363480 ms
# GFLOPS: 0.177167
# Elapsed time: 225413.030444 ms
# GFLOPS: 0.177452
# Elapsed time: 224690.438361 ms
# GFLOPS: 0.178023
# Elapsed time: 224934.833417 ms
# GFLOPS: 0.177829

# %%
# !nvcc -arch=sm_75 ./ej6.cu -o ej6

# !./ej6 256
# !./ej6 256
# !./ej6 256
# !./ej6 256
# !./ej6 256
# Out:
# Using 390625 blocks of 256 threads
# Time elapsed: 10333.632812 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10465.818359 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10696.263672 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 10909.836914 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 11034.091797 ms
# Success! All values are correct.

# %% [markdown]
# --

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.96 KiB | 1004.00 KiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    449cf1d..0cb6c60  main       -> origin/main
# Updating 449cf1d..0cb6c60
# Fast-forward
#  ej8.txt                | 18 ++++++++---
#  ej8_ultra_optimized.cu | 16 +++++-----
#  pract2.ipynb           | 85 +++++++++++++++++++++++++++++++-------------------
#  3 files changed, 75 insertions(+), 44 deletions(-)

# %% [markdown]
# ## CPU

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_cpu.cu -o ej8_cpu

# %%
# !./ej8_cpu
# Out:
# Elapsed time: 324755.684563 ms

# %% [markdown]
# ## GPU - Sin optimizar

# %%
# !nvcc -O3 -arch=sm_75 ./ej8.cu -o ej8

# %%
# !./ej8 128
# !./ej8 128
# !./ej8 128
# !./ej8 128
# !./ej8 128

# !./ej8 256
# !./ej8 256
# !./ej8 256
# !./ej8 256
# !./ej8 256

# !./ej8 512
# !./ej8 512
# !./ej8 512
# !./ej8 512
# !./ej8 512
# Out:
# Using 7813 blocks of 128 threads
# Time elapsed: 4507.012207 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Time elapsed: 4357.568359 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Time elapsed: 4401.600098 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Time elapsed: 4399.937500 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 7813 blocks of 128 threads
# Time elapsed: 4432.089844 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 256 threads
# Time elapsed: 4453.189453 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 256 threads
# Time elapsed: 4470.332520 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 256 threads
# Time elapsed: 4489.688477 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 256 threads
# Time elapsed: 4504.888184 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 256 threads
# Time elapsed: 4538.066895 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 512 threads
# Time elapsed: 4564.826660 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 512 threads
# Time elapsed: 4581.382324 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 512 threads
# Time elapsed: 4595.101562 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 512 threads
# Time elapsed: 4636.572754 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 512 threads
# Time elapsed: 4672.068848 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!

# %%
# !./ej8 64
# !./ej8 64
# !./ej8 64
# !./ej8 64
# !./ej8 64
# Out:
# Using 15625 blocks of 64 threads
# Time elapsed: 4569.012207 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Time elapsed: 4424.516113 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Time elapsed: 4450.938965 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Time elapsed: 4473.990723 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 15625 blocks of 64 threads
# Time elapsed: 4501.110352 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!

# %% [markdown]
# ## GPU - Pre-calculando la suma de b

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_optimized.cu -o ej8_optimized

# %%
# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256

# !./ej8_optimized 128
# !./ej8_optimized 128
# !./ej8_optimized 128
# !./ej8_optimized 128
# !./ej8_optimized 128

# !./ej8_optimized 512
# !./ej8_optimized 512
# !./ej8_optimized 512
# !./ej8_optimized 512
# !./ej8_optimized 512
# Out:
# Using 390625 blocks of 256 threads
# Time elapsed: 133.394241 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 390625 blocks of 256 threads
# Time elapsed: 133.266296 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 390625 blocks of 256 threads
# Time elapsed: 133.141312 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 390625 blocks of 256 threads
# Time elapsed: 133.029190 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 390625 blocks of 256 threads
# Time elapsed: 132.989731 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 781250 blocks of 128 threads
# Time elapsed: 134.610626 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 781250 blocks of 128 threads
# Time elapsed: 133.324448 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 781250 blocks of 128 threads
# Time elapsed: 133.002365 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 781250 blocks of 128 threads
# Time elapsed: 143.835938 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 781250 blocks of 128 threads
# Time elapsed: 137.680832 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 195313 blocks of 512 threads
# Time elapsed: 132.610886 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 195313 blocks of 512 threads
# Time elapsed: 133.304352 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 195313 blocks of 512 threads
# Time elapsed: 132.371841 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 195313 blocks of 512 threads
# Time elapsed: 132.356735 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 195313 blocks of 512 threads
# Time elapsed: 132.468155 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!

# %%
# !./ej8_optimized 64
# !./ej8_optimized 64
# !./ej8_optimized 64
# !./ej8_optimized 64
# !./ej8_optimized 64
# Out:
# Using 1562500 blocks of 64 threads
# Time elapsed: 133.566757 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 1562500 blocks of 64 threads
# Time elapsed: 133.724701 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 1562500 blocks of 64 threads
# Time elapsed: 139.118881 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 1562500 blocks of 64 threads
# Time elapsed: 136.216507 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 1562500 blocks of 64 threads
# Time elapsed: 133.168411 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!

# %%
# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256
# !./ej8_optimized 256
# Out:
# Using 390625 blocks of 256 threads
# Time elapsed: 132.585403 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 390625 blocks of 256 threads
# Time elapsed: 132.446945 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 390625 blocks of 256 threads
# Time elapsed: 133.262756 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 390625 blocks of 256 threads
# Time elapsed: 133.204987 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!
# Using 390625 blocks of 256 threads
# Time elapsed: 133.118332 ms
# Expected: 33554432.000000, Got: 33554432.000000
# Success!

# %% [markdown]
# ## GPU - Ejecutando 4 instrucciones por thread para aprovechar el ILP

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_super_optimized.cu -o ej8_super_optimized

# %%
# !./ej8_super_optimized 64
# !./ej8_super_optimized 64
# !./ej8_super_optimized 64
# !./ej8_super_optimized 64
# !./ej8_super_optimized 64

# !./ej8_super_optimized 128
# !./ej8_super_optimized 128
# !./ej8_super_optimized 128
# !./ej8_super_optimized 128
# !./ej8_super_optimized 128

# !./ej8_super_optimized 256
# !./ej8_super_optimized 256
# !./ej8_super_optimized 256
# !./ej8_super_optimized 256
# !./ej8_super_optimized 256


# !./ej8_super_optimized 512
# !./ej8_super_optimized 512
# !./ej8_super_optimized 512
# !./ej8_super_optimized 512
# !./ej8_super_optimized 512
# Out:
# Using 3907 blocks of 64 threads
# Time elapsed: 1.452160 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 64 threads
# Time elapsed: 1.519648 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 64 threads
# Time elapsed: 1.444512 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 64 threads
# Time elapsed: 1.478848 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 3907 blocks of 64 threads
# Time elapsed: 1.532736 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 128 threads
# Time elapsed: 1.536224 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 128 threads
# Time elapsed: 1.504896 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 128 threads
# Time elapsed: 2.266208 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 128 threads
# Time elapsed: 1.554368 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 1954 blocks of 128 threads
# Time elapsed: 1.480640 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 977 blocks of 256 threads
# Time elapsed: 1.557984 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 977 blocks of 256 threads
# Time elapsed: 1.530752 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 977 blocks of 256 threads
# Time elapsed: 1.458432 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 977 blocks of 256 threads
# Time elapsed: 1.478336 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 977 blocks of 256 threads
# Time elapsed: 1.462400 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 489 blocks of 512 threads
# Time elapsed: 1.475776 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 489 blocks of 512 threads
# Time elapsed: 1.459712 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 489 blocks of 512 threads
# Time elapsed: 1.470336 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 489 blocks of 512 threads
# Time elapsed: 1.451616 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!
# Using 489 blocks of 512 threads
# Time elapsed: 1.568704 ms
# Expected: 2000000.000000, Got: 2000000.000000
# Success!

# %% [markdown]
# ## GPU - Calculando la suma de b en paralelo

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_ultra_optimized.cu -o ej8_ultra_optimized

# %%
# !./ej8_ultra_optimized 64 2
# !./ej8_ultra_optimized 64 2
# !./ej8_ultra_optimized 64 2
# !./ej8_ultra_optimized 64 2
# !./ej8_ultra_optimized 64 2

# !./ej8_ultra_optimized 128 2
# !./ej8_ultra_optimized 128 2
# !./ej8_ultra_optimized 128 2
# !./ej8_ultra_optimized 128 2
# !./ej8_ultra_optimized 128 2

# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2

# !./ej8_ultra_optimized 512 2
# !./ej8_ultra_optimized 512 2
# !./ej8_ultra_optimized 512 2
# !./ej8_ultra_optimized 512 2
# !./ej8_ultra_optimized 512 2
# Out:
# Using 1562500 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.991295 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 1562500 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.765823 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 1562500 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.632126 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 1562500 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.542526 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 1562500 blocks of 64 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.385437 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 781250 blocks of 128 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.763969 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 781250 blocks of 128 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.955650 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 781250 blocks of 128 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.630402 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 781250 blocks of 128 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.645508 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 781250 blocks of 128 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 72.402237 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 120.211586 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 82.365059 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.180733 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.161278 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.589188 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 195313 blocks of 512 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.182365 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 195313 blocks of 512 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.662819 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 195313 blocks of 512 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.631523 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 195313 blocks of 512 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.444321 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 195313 blocks of 512 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 71.096222 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!

# %%
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2
# !./ej8_ultra_optimized 256 2

# !./ej8_ultra_optimized 256 4
# !./ej8_ultra_optimized 256 4
# !./ej8_ultra_optimized 256 4
# !./ej8_ultra_optimized 256 4
# !./ej8_ultra_optimized 256 4

# !./ej8_ultra_optimized 256 8
# !./ej8_ultra_optimized 256 8
# !./ej8_ultra_optimized 256 8
# !./ej8_ultra_optimized 256 8
# !./ej8_ultra_optimized 256 8

# !./ej8_ultra_optimized 256 12
# !./ej8_ultra_optimized 256 12
# !./ej8_ultra_optimized 256 12
# !./ej8_ultra_optimized 256 12
# !./ej8_ultra_optimized 256 12
# Out:
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.534882 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.500160 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 71.490242 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 70.883423 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed: 69.307137 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 4 CPU threads for parallel sum
# Time elapsed: 70.788574 ms
# Expected: 134217728.000000, Got: 134217728.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 4 CPU threads for parallel sum
# Time elapsed: 70.078178 ms
# Expected: 134217728.000000, Got: 134217728.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 4 CPU threads for parallel sum
# Time elapsed: 70.439232 ms
# Expected: 134217728.000000, Got: 134217728.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 4 CPU threads for parallel sum
# Time elapsed: 70.490463 ms
# Expected: 134217728.000000, Got: 134217728.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 4 CPU threads for parallel sum
# Time elapsed: 115.502174 ms
# Expected: 134217728.000000, Got: 134217728.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 8 CPU threads for parallel sum
# Time elapsed: 112.941956 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 8 CPU threads for parallel sum
# Time elapsed: 69.799904 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 8 CPU threads for parallel sum
# Time elapsed: 70.015999 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 8 CPU threads for parallel sum
# Time elapsed: 69.526878 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 8 CPU threads for parallel sum
# Time elapsed: 69.549919 ms
# Expected: 200000000.000000, Got: 200000000.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 12 CPU threads for parallel sum
# Time elapsed: 69.879745 ms
# Expected: 200000032.000000, Got: 200000032.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 12 CPU threads for parallel sum
# Time elapsed: 69.744637 ms
# Expected: 200000032.000000, Got: 200000032.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 12 CPU threads for parallel sum
# Time elapsed: 81.868095 ms
# Expected: 200000032.000000, Got: 200000032.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 12 CPU threads for parallel sum
# Time elapsed: 70.707489 ms
# Expected: 200000032.000000, Got: 200000032.000000
# Success!
# Using 390625 blocks of 256 threads
# Using 12 CPU threads for parallel sum
# Time elapsed: 71.585411 ms
# Expected: 200000032.000000, Got: 200000032.000000
# Success!

# %% [markdown]
# ## Desglose de tiempos Suma vs Kernel

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_ultra_optimized_times.cu -o ej8_ultra_optimized_times

# %%
# !./ej8_ultra_optimized_times 256 2
# Out:
# Using 390625 blocks of 256 threads
# Using 2 CPU threads for parallel sum
# Time elapsed (total): 69.301155 ms
#   - Parallel sum (CPU): 65.823135 ms
#   - Kernel execution (GPU): 3.469184 ms
# Expected: 67108864.000000, Got: 67108864.000000
# Success!

# %% [markdown]
# ## Suma en paralelo en la GPU

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.14 KiB | 586.00 KiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    978a584..ed95e39  main       -> origin/main
# Updating 978a584..ed95e39
# Fast-forward
#  ej8_sum_gpu.cu |  2 +-
#  pract2.ipynb   | 21 +++++++++++----------
#  2 files changed, 12 insertions(+), 11 deletions(-)

# %%
# !nvcc -O3 -arch=sm_75 ./ej8_sum_gpu.cu -o ej8_sum_gpu
# Out:
# ./ej8_sum_gpu.cu(95): error: argument of type "float *" is incompatible with parameter of type "float"
#       vector_pro<<<blocks, threadsPerBlock>>>(out_cuda, a_cuda, result_cuda, 100000000);
#                                                                 ^
#
# 1 error detected in the compilation of "./ej8_sum_gpu.cu".

# %%
# !./ej8_sum_gpu 256 256
# Out:
# Using 390625 blocks of 256 threads for vector_pro
# Using 390625 blocks of 256 threads for sum kernel
# Elements per thread: 1
# Sum kernel launched
