# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.12/dist-packages (1.2.1)
# The nvcc4jupyter extension is already loaded. To reload it, use:
#   %reload_ext nvcc4jupyter

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# fatal: destination path 'sci_pract2_cuda' already exists and is not an empty directory.
# /content/sci_pract2_cuda
# Already up to date.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.23 KiB | 1.23 MiB/s, done.
# From https://github.com/PabloGonzalezSegarra/sci_pract2_cuda
#    48fb08f..5f4ea15  main       -> origin/main
# Updating 48fb08f..5f4ea15
# Fast-forward
#  pract2.ipynb      | 60 ++++++++++++-------------------------------------------
#  vector_add_mod.cu | 13 ++++++------
#  2 files changed, 19 insertions(+), 54 deletions(-)

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !git pull > /dev/null 2>&1
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod
# Out:
# Time elapsed: 5887.441895 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# Out:
# Time elapsed: 5851.866211 ms
# Success! All values are correct.
# Time elapsed: 5740.338867 ms
# Success! All values are correct.
# Time elapsed: 5776.577637 ms
# Success! All values are correct.
# Time elapsed: 5746.441406 ms
# Success! All values are correct.
# Time elapsed: 5732.568848 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# Out:
# Time elapsed: 5727.944824 ms
# Success! All values are correct.
# Time elapsed: 5730.535156 ms
# Success! All values are correct.
# Time elapsed: 5728.185059 ms
# Success! All values are correct.
# Time elapsed: 5773.969727 ms
# Success! All values are correct.
# Time elapsed: 5785.547852 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# Out:
# Time elapsed: 5731.747559 ms
# Success! All values are correct.
# Time elapsed: 5727.559570 ms
# Success! All values are correct.
# Time elapsed: 5725.850586 ms
# Success! All values are correct.
# Time elapsed: 5748.966309 ms
# Success! All values are correct.
# Time elapsed: 5775.850586 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# Out:
# Time elapsed: 5792.949219 ms
# Success! All values are correct.
# Time elapsed: 5756.698730 ms
# Success! All values are correct.
# Time elapsed: 5800.102051 ms
# Success! All values are correct.
# Time elapsed: 5730.846680 ms
# Success! All values are correct.
# Time elapsed: 5732.838379 ms
# Success! All values are correct.
