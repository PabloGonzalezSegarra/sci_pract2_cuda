# %%
# %pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Requirement already satisfied: nvcc4jupyter in /usr/local/lib/python3.12/dist-packages (1.2.1)
# The nvcc4jupyter extension is already loaded. To reload it, use:
#   %reload_ext nvcc4jupyter

# %%
# !git clone https://github.com/PabloGonzalezSegarra/sci_pract2_cuda.git || true
# %cd sci_pract2_cuda
# Out:
# fatal: destination path 'sci_pract2_cuda' already exists and is not an empty directory.
# /content/sci_pract2_cuda
# Already up to date.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !nvcc -arch=sm_75 ./gpu_check.cu -o gpu_check
# !./gpu_check
# Out:
# Using GPU 0: Tesla T4
# Value read from kernel: 12345

# %%
# !git pull > /dev/null 2>&1
# !nvcc -arch=sm_75 ./vector_add_mod.cu -o vector_add_mod
# !./vector_add_mod

# %%
# !nvcc -arch=sm_75 ./vector_add_cpu.cu -o vector_add_cpu
# !./vector_add_cpu 
# !./vector_add_cpu
# !./vector_add_cpu
# !./vector_add_cpu
# !./vector_add_cpu
# Out:
# Elapsed time: 995.965764 ms
# Elapsed time: 992.593305 ms
# Elapsed time: 1000.372240 ms
# Elapsed time: 999.341579 ms
# Elapsed time: 994.057475 ms

# %%
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# !./vector_add_mod 1
# Out:
# Using 100000000 blocks of 1 threads
# Time elapsed: 640.056091 ms
# Success! All values are correct.
# Using 100000000 blocks of 1 threads
# Time elapsed: 537.119080 ms
# Success! All values are correct.
# Using 100000000 blocks of 1 threads
# Time elapsed: 586.800232 ms
# Success! All values are correct.
# Using 100000000 blocks of 1 threads
# Time elapsed: 537.561768 ms
# Success! All values are correct.
# Using 100000000 blocks of 1 threads
# Time elapsed: 532.061707 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# !./vector_add_mod 16
# Out:
# Using 6250000 blocks of 16 threads
# Time elapsed: 438.736694 ms
# Success! All values are correct.
# Using 6250000 blocks of 16 threads
# Time elapsed: 441.000031 ms
# Success! All values are correct.
# Using 6250000 blocks of 16 threads
# Time elapsed: 443.602570 ms
# Success! All values are correct.
# Using 6250000 blocks of 16 threads
# Time elapsed: 446.069092 ms
# Success! All values are correct.
# Using 6250000 blocks of 16 threads
# Time elapsed: 445.288361 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# !./vector_add_mod 32
# Out:
# Using 3125000 blocks of 32 threads
# Time elapsed: 504.018219 ms
# Success! All values are correct.
# Using 3125000 blocks of 32 threads
# Time elapsed: 434.033112 ms
# Success! All values are correct.
# Using 3125000 blocks of 32 threads
# Time elapsed: 443.444641 ms
# Success! All values are correct.
# Using 3125000 blocks of 32 threads
# Time elapsed: 432.151733 ms
# Success! All values are correct.
# Using 3125000 blocks of 32 threads
# Time elapsed: 437.758911 ms
# Success! All values are correct.

# %%
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# !./vector_add_mod 256
# Out:
# Using 390625 blocks of 256 threads
# Time elapsed: 432.925293 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 432.490997 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 444.291046 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 494.588196 ms
# Success! All values are correct.
# Using 390625 blocks of 256 threads
# Time elapsed: 433.968018 ms
# Success! All values are correct.
